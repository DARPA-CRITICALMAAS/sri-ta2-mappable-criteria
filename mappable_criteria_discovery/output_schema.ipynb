# %%
import os
import json
import yaml
import argparse
from collections import OrderedDict

import pandas as pd
import numpy as np

# %%
cfg_file = 'configs/base_config.yaml'

# %%
with open(cfg_file) as f:
        cfg = yaml.load(f, Loader=yaml.FullLoader)

doc_metadata = pd.read_csv(os.path.join(cfg['data_dir'], 'metadata.csv'))

# paths
doc_dir = os.path.join(
    cfg['log_dir'], cfg['text_extraction']['doc_dir']
)

min_sys_dir = os.path.join(
    cfg['log_dir'], cfg['mineral_system']['response_dir']
)

map_cri_dir = os.path.join(
    cfg['log_dir'], cfg['mappable_criteria']['response_dir']
)

map_layer_ppl_dir = os.path.join(
    cfg['log_dir'], cfg['map_layers']['response_ppl_dir']
)

map_layer_df = pd.read_csv(cfg["map_layers"]['map_layer_file'])
map_layer_df = map_layer_df[['Method', 'Method sub-type', 'Dataset description', 'Dataset name']]
map_layer_df = map_layer_df[map_layer_df['Method sub-type'] != 'Training data']
map_layer_list = map_layer_df.apply(':'.join, axis=1).to_list()

# %%
components = list(cfg['mappable_criteria']['llm_config']['definition'].keys())
mineral_system = {k:[] for k in components}
mineral_system
# Out:
# {'source': [], 'pathway': [], 'trap': [], 'preservation': []}

# %%
doc_metadata.id.to_list()
# Out:
# ['SIR10-5070A']

# %%
def load_responses_map_layer(fname):
    # import ipdb; ipdb.set_trace()
    responses = {}
    with open(fname, 'r') as f:
        for line in f.readlines():
            item_list = json.loads(line)
            if len(item_list) == 2:
                request, response = item_list
            elif len(item_list) == 3:
                request, response, metadata = item_list
            else:
                print("error!")
            # responses.append({
            #     'response': response['choices'][0]['message']['content'], 'metadata': metadata
            #     })
            node_id = metadata['node_id']
            map_layer_id = metadata['map_layer_id']
            if node_id not in responses:
                responses[node_id] = {map_layer_id: response['choices'][0]['logprobs']['content']}
            else:
                responses[node_id][map_layer_id] = response['choices'][0]['logprobs']['content']
            # responses.append({
            #     'response': response['choices'][0]['logprobs']['content'], 'metadata': metadata
            #     })
            
    return responses

# %%
def load_response_map_cri(fname):
    map_cri_response = {}
    with open(fname, 'r') as f:
        for line in f.readlines():
            items = json.loads(line)
            if len(items) == 2:
                request, response = items
            elif len(items) == 3:
                request, response, metadata = items
            else:
                print("error!")
            map_cri_response[metadata['node_id']] = {
                'component': metadata['component'],
                'response': response['choices'][0]['message']['content'].replace('\n\n', '\n')
            }
    return map_cri_response

# %%
fnames = [fname+'.jsonl' for fname in doc_metadata.id.to_list()]
for fname in fnames:
    
    file_id = fname.split('.')[0]
    doc_fname = os.path.join(doc_dir, file_id + '.json')
    with open(doc_fname, 'r') as f:
        doc = json.load(f, object_pairs_hook=OrderedDict)
    
    doc_meta = doc_metadata[doc_metadata["id"] == file_id].iloc[0].to_dict()

    map_cri_file = os.path.join(map_cri_dir, fname)
    map_cri_response = load_response_map_cri(map_cri_file)
    
    map_layer_file = os.path.join(map_layer_ppl_dir, fname)
    map_layer_response = load_responses_map_layer(map_layer_file)

    for node_id in map_cri_response:
        comp = map_cri_response[node_id]['component']
        map_cri = map_cri_response[node_id]['response']

        map_layer_dict = []
        for i in range(len(map_layer_list)):
            top_logprobs = map_layer_response[node_id][i][0]['top_logprobs']
            for l in top_logprobs:
                if l['token'].lower() == 'yes':
                    map_layer_dict.append({
                        "name":map_layer_list[i],
                        "relevance_score": np.exp(l['logprob']),
                    })
        map_layers_sorted = sorted(map_layer_dict, key=lambda d: d['relevance_score'], reverse=True)  # descending order

        mineral_system[comp].append({
            "criteria": map_cri,
            "theoretical": "N/A",
            "potential_dataset": map_layers_sorted[:5],
            "supporting_references": [{
                # "id": file_id,
                "document": doc_meta,
                "page_info": [{"text": doc[node_id]["text"], "page": doc[node_id]["page"], "bounding_box": doc[node_id]["coords"]}]
            }]
        })

# %%
mineral_system
# Out:
# {'source': [{'criteria': 'The mappable proxy that represents the geological features related to the source of MVT Lead-Zinc deposits could be fracture density and permeability.',
#    'theoretical': 'N/A',
#    'potential_dataset': [{'name': 'Geology:Fault:Proximity to fault (pixels; calculated from raster with 0.01 degree grid):Geology_Fault_Proximity',
#      'relevance_score': 0.998837718273238},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Cherty',
#      'relevance_score': 0.9732007737651269},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Evaporitic',
#      'relevance_score': 0.9639554713346702},
#     {'name': 'Geophysics:Gravity:Bouguer gravity anomaly (mGal):Gravity_Bouguer',
#      'relevance_score': 0.958305782047392},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Intermediate',
#      'relevance_score': 0.9581814374820325},
#     {'name': 'Geology:Geochronology:Precense or absence of H3 cells with two or more geological periods:Geology_Period_Contact',
#      'relevance_score': 0.9503339935658379},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Calcareous',
#      'relevance_score': 0.9493567680282919},
#     {'name': 'Geophysics:Gravity:Upward-continued (30 km) horizontal gradient magnitude (HGM):Gravity_Bouguer_UpCont30km_HGM',
#      'relevance_score': 0.9433196145486518},
#     {'name': 'Geology:Lithological contacts:Precense or absence of H3 cells with two or more lithologies:Geology_Lithology_Contact',
#      'relevance_score': 0.9429417058706847},
#     {'name': 'Geology:Geological terrane:Precense or absence of H3 cells with two or more terrane names:Terrane_Contact',
#      'relevance_score': 0.9393203003537448},
#     {'name': 'Geophysics:Magnetic:1st vertical derivative (1VD; nT/m):Magnetic_1VD',
#      'relevance_score': 0.9274641607017038},
#     {'name': 'Geophysics:Magnetotelluric:Global resistivity (ohm-m):Magnetotelluric',
#      'relevance_score': 0.9206428343041166},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Sedimentary',
#      'relevance_score': 0.9152269515328009},
#     {'name': 'Geophysics:Gravity:Bouguer gravity anomaly (mGal):Gravity_Bouguer_BGI',
#      'relevance_score': 0.9132220488651331},
#     {'name': 'Geology:Geological terrane:Terrane name (raster value with the largest sum of coverage fractions):Terrane_Majority',
#      'relevance_score': 0.8934376397921615},
#     {'name': 'Geophysics:Gravity:Upward-continued (30 km) gravity anomaly (mGal):Gravity_Bouguer_UpCont30km',
#      'relevance_score': 0.8905155538336138},
#     {'name': 'Geophysics:Magnetic:Long-wavelength horizontal gradient magnitude (HGM):Magnetic_LongWavelength_HGM',
#      'relevance_score': 0.8815082219159665},
#     {'name': 'Geophysics:Gravity:Horizontal gradient magnitude (HGM):Gravity_Bouguer_HGM',
#      'relevance_score': 0.8765555320842616},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Schistose',
#      'relevance_score': 0.8698150640388627},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) maximum curvature derivative:Gravity_GOCE_MaximumCurve',
#      'relevance_score': 0.8663220390268748},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) differential curvature deriverative:Gravity_GOCE_Differential',
#      'relevance_score': 0.8593437606771207},
#     {'name': 'Geophysics:Magnetic:Magnetic reduced-to-pole (RTP; nT):Magnetic_RTP',
#      'relevance_score': 0.8546153109560861},
#     {'name': 'Geology:Geological terrane:Proximity to terrane boundary (pixels; calculated from raster with 0.01 degree grid):Terrane_Proximity',
#      'relevance_score': 0.8494041969832283},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Carbonaceous',
#      'relevance_score': 0.8158795052960184},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) minimum curvature derivative:Gravity_GOCE_MinimumCurve',
#      'relevance_score': 0.8146112690652167},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_FineClastic',
#      'relevance_score': 0.8131443361109607},
#     {'name': 'Geophysics:Magnetic:Horizontal gradient magnitude (HGM):Magnetic_HGM',
#      'relevance_score': 0.8088460311497613},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) shape index:Gravity_GOCE_ShapeIndex',
#      'relevance_score': 0.805801399051231},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Gneissose',
#      'relevance_score': 0.8037879486904469},
#     {'name': 'Geology:Lithology:Lithology sub-type (raster value with the smallest sum of coverage fraction):Geology_Lithology_Minority',
#      'relevance_score': 0.8025536280341171},
#     {'name': 'Geology:Lithology:Lithology sub-type (raster value with the largest sum of coverage fraction):Geology_Lithology_Majority',
#      'relevance_score': 0.7877656908323464},
#     {'name': 'Geology:Paleo-longitude:Calculated paleo-longitude based on maximum period (degrees):Geology_Paleolongitude_Period_Maximum',
#      'relevance_score': 0.7839315665541436},
#     {'name': 'Geology:Geochronology:Maximum Era name (raster value with the largest sum of coverage fraction):Geology_Era_Maximum_Majority',
#      'relevance_score': 0.783623259874857},
#     {'name': 'Geology:Geological terrane:Terrane name (raster value with the smallest sum of coverage fractions):Terrane_Minority',
#      'relevance_score': 0.7788691492046885},
#     {'name': 'Geology:Geochronology:Minimum Eera name (raster value with the smallest sum of coverage fraction):Geology_Era_Minimum_Minority',
#      'relevance_score': 0.7575118486036145},
#     {'name': 'Geology:Black shale:Proximity to black shale (pixels; calculated from raster with 0.01 degree grid):Geology_BlackShale_Proximity',
#      'relevance_score': 0.7439851306754782},
#     {'name': 'Geophysics:Magnetic:Depth to Curie-point (km):Magnetic_EMAG2v3_CuriePoint',
#      'relevance_score': 0.7423592266632294},
#     {'name': 'Geology:Geochronology:Minimum Period name (raster value with the largest sum of coverage fraction):Geology_Period_Minimum_Majority',
#      'relevance_score': 0.7416720237813611},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_RedBed',
#      'relevance_score': 0.714613972991124},
#     {'name': 'Geophysics:Magnetic:Upward-continued (4 km; nT):Magnetic_EMAG2v3',
#      'relevance_score': 0.7084292171957374},
#     {'name': 'Geophysics:Lithospheric models:Crustal density  (kg m-3):Litmod_Density_Crust',
#      'relevance_score': 0.7082085121224839},
#     {'name': 'Geophysics:Seismic:Seismic velocity at 50 km depth (km s–1):Seismic_Velocity_050km',
#      'relevance_score': 0.6886993226166964},
#     {'name': 'Geology:Paleo-longitude:Calculated paleo-longitude based on minimum period (degrees):Geology_Paleolongitude_Period_Minimum',
#      'relevance_score': 0.6847450361549625},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) mean curvature derivative:Gravity_GOCE_MeanCurve',
#      'relevance_score': 0.6801910937977376},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Pegmatitic',
#      'relevance_score': 0.679495763596349},
#     {'name': 'Geophysics:Heat Flow:Global surface heat flow (mWm−2):HeatFlow',
#      'relevance_score': 0.6600043850292664},
#     {'name': 'Geophysics:Crustal models:Sediment thickness (m):Crust1_SedimentThickness',
#      'relevance_score': 0.6578605698728889},
#     {'name': 'Geology:Cover thickness:Cover thickness (m):Geology_CoverThickness',
#      'relevance_score': 0.6472059887232473},
#     {'name': 'Geophysics:Crustal models:Crustal thickness (km):Crust1_CrustalThickness',
#      'relevance_score': 0.6415828646518031},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_CoarseClastic',
#      'relevance_score': 0.6219309159599026},
#     {'name': 'Information:Discrete Global Grid System (DGGS) cell ID:H3 cell address:H3_Address',
#      'relevance_score': 0.6140468934833111},
#     {'name': 'Geology:Geochronology:Minimum Era name (raster value with the largest sum of coverage fraction):Geology_Era_Minimum_Majority',
#      'relevance_score': 0.6121001169876927},
#     {'name': 'Geology:Paleo-latitude:Calculated paleo-latitude based on maximum period (degrees):Geology_Paleolatitude_Period_Maximum',
#      'relevance_score': 0.5794984737162605},
#     {'name': 'Geology:Geochronology:Maximum Eon name (raster value with the largest sum of coverage fraction):Geology_Eon_Maximum_Majority',
#      'relevance_score': 0.5781119175928913},
#     {'name': 'Geophysics:Lithospheric models:Lithospheric density  (kg m-3):Litmod_Density_Lithosphere',
#      'relevance_score': 0.5756778862335522},
#     {'name': 'Geology:Passive margin:Proximity to passive margin (pixels; calculated from raster with 0.01 degree grid):Geology_PassiveMargin_Proximity',
#      'relevance_score': 0.5734826475362133},
#     {'name': 'Geophysics:Gravity:Proximity to upward-continued (30 km) worms (pixels; calculated from raster with 0.01 degree grid):Gravity_Bouguer_UpCont30km_HGM_Worms_Proximity',
#      'relevance_score': 0.5652422379408438},
#     {'name': 'Information:Discrete Global Grid System (DGGS) resolution:H3 cell resolution:H3_Resolution',
#      'relevance_score': 0.5646323881706227},
#     {'name': 'Geology:Geochronology:Maximum Period name (raster value with the smallest sum of coverage fraction):Geology_Period_Maximum_Minority',
#      'relevance_score': 0.5617804858293991},
#     {'name': 'Geology:Geochronology:Minimum Period name (raster value with the smallest sum of coverage fraction):Geology_Period_Minimum_Minority',
#      'relevance_score': 0.5582945212424111},
#     {'name': 'Information:Discrete Global Grid System (DGGS) cell coordinates:Longitude of central point calculated using the sf package (coordinates reported as decimal degrees and are based on WGS84; EPSG4326):Longitude_EPSG4326',
#      'relevance_score': 0.5533920375329446},
#     {'name': 'Geology:Geochronology:Maximum Eon name (raster value with the smallest sum of coverage fraction):Geology_Eon_Maximum_Minority',
#      'relevance_score': 0.5377061541012468},
#     {'name': 'Information:Discrete Global Grid System (DGGS) cell coordinates:Latitude of central point calculated using the sf package (coordinates reported as decial degrees and are based on WGS84; EPSG4326):Latitude_EPSG4326',
#      'relevance_score': 0.5318031111312175},
#     {'name': 'Geology:Geochronology:Maximum Period name (raster value with the largest sum of coverage fraction):Geology_Period_Maximum_Majority',
#      'relevance_score': 0.526193217523534},
#     {'name': 'Geophysics:Crustal models:Crust type name:Crust1_Type',
#      'relevance_score': 0.5013382780788034},
#     {'name': 'Geology:Geochronology:Minimum Eon name (raster value with the largest sum of coverage fraction):Geology_Eon_Minimum_Majority',
#      'relevance_score': 0.49920107923508467},
#     {'name': 'Geology:Paleo-latitude:Calculated paleo-latitude based on minimum period (degrees):Geology_Paleolatitude_Period_Minimum',
#      'relevance_score': 0.4895541696042325},
#     {'name': 'Information:Geography:Province, state, or territory name (raster value with the largest sum of coverage fractions) :Province_Majority',
#      'relevance_score': 0.4795036848079781},
#     {'name': 'Geophysics:Seismic:Depth to lithosphere-asthenosphere boundary (LAB; km):Seismic_LAB_Hoggard',
#      'relevance_score': 0.4711991266998202},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Felsic',
#      'relevance_score': 0.4702290982287059},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_UltramaficMafic',
#      'relevance_score': 0.46837664955796304},
#     {'name': 'Geology:Geochronology:Maximum Era name (raster value with the smallest sum of coverage fraction):Geology_Era_Maximum_Minority',
#      'relevance_score': 0.42931382529318335},
#     {'name': 'Geophysics:Magnetic:Proximity to long-wavlength worms (pixels; calculated from raster with 0.01 degree grid):Magnetic_LongWavelength_HGM_Worms_Proximity',
#      'relevance_score': 0.4126425983399943},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Anatectic',
#      'relevance_score': 0.3572334461945409},
#     {'name': 'Geophysics:Seismic:Seismic velocity at 100 km depth (km s-1):Seismic_Velocity_100km',
#      'relevance_score': 0.33421432506173004},
#     {'name': 'Geophysics:Seismic:Seismic velocity at 150 km depth (km s–1):Seismic_Velocity_150km',
#      'relevance_score': 0.3261947445673377},
#     {'name': 'Information:Geography:Continent name (raster value with the largest sum of coverage fractions) :Continent_Majority',
#      'relevance_score': 0.31894567133380014},
#     {'name': 'Geology:Geochronology:Minimum Eon name (raster value with the smallest sum of coverage fraction):Geology_Eon_Minimum_Minority',
#      'relevance_score': 0.3187011975362542},
#     {'name': 'Information:Discrete Global Grid System (DGGS) geometry:H3 cell polygon geometry calculated using the sf package (Well Known Text, WKT, format; EPSG4326):H3_Geometry',
#      'relevance_score': 0.3182789434626373},
#     {'name': 'Geophysics:Seismic:Depth to lithosphere-asthenosphere boundary (LAB; km):Seismic_LAB_Priestley',
#      'relevance_score': 0.30213881950100807},
#     {'name': 'Geophysics:Lithospheric models:Asthenospheric density (kg m-3):Litmod_Density_Asthenosphere',
#      'relevance_score': 0.2991699417481973},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Alkalic',
#      'relevance_score': 0.2788013382699121},
#     {'name': 'Geophysics:Seismic:Seismic velocity at 200 km depth (km s–1):Seismic_Velocity_200km',
#      'relevance_score': 0.2675935644922148},
#     {'name': 'Geophysics:Gravity:Proximity to gravity worms (pixels; calculated from raster with 0.01 degree grid):Gravity_Bouguer_HGM_Worms_Proximity',
#      'relevance_score': 0.24531067758153388},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Igneous',
#      'relevance_score': 0.23818226001554224},
#     {'name': 'Information:Geography:Country name (raster value with the largest sum of coverage fractions) :Country_Majority',
#      'relevance_score': 0.2352613629709579},
#     {'name': 'Information:Geography:Province, state, or territory name (raster value with the smallest sum of coverage fractions) :Province_Minority',
#      'relevance_score': 0.22422680882545368},
#     {'name': 'Geophysics:Magnetic:Proximity to magnetic worms (pixels; calculated from raster with 0.01 degree grid):Magnetic_HGM_Worms_Proximity',
#      'relevance_score': 0.183392832713955},
#     {'name': 'Geophysics:Seismic:Depth to Mohorovičić discontinuity or Moho (km):Seismic_Moho_GEMMA',
#      'relevance_score': 0.13229666712202168},
#     {'name': 'Geophysics:Seismic:Depth to Mohorovičić discontinuity or Moho (km):Seismic_Moho_Szwillus',
#      'relevance_score': 0.09374993569986113},
#     {'name': 'Geophysics:Seismic:Depth to Mohorovičić discontinuity or Moho (km):Seismic_Moho',
#      'relevance_score': 0.08218660059506006},
#     {'name': 'Information:Geography:Continent name (raster value with the smallest sum of coverage fractions):Continent_Minority',
#      'relevance_score': 0.07588146707167683},
#     {'name': 'Information:Geography:Country name (raster with the smallest sum of coverage fractions):Country_Minority',
#      'relevance_score': 0.04518660435029259}],
#    'supporting_references': [{'document': {'id': 'SIR10-5070A',
#       'title': 'A Deposit Model for Mississippi Valley-Type Lead-Zinc Ores',
#       'doi': '10.3133/sir20105070A',
#       'uri': 'https://pubs.usgs.gov/sir/2010/5070/a/pdf/SIR10-5070A.pdf',
#       'authors': 'David L. Leach, Ryan D. Taylor, David L. Fey, Sharon F. Diehl, and Richard W. Saltus',
#       'journal': 'Scientific Investigations Report 2010-5070-A',
#       'year': 2010,
#       'month': nan,
#       'volume': nan,
#       'issue': nan,
#       'description': nan},
#      'page_info': [{'text': '19\nMetal Contents .20\nStable Isotope Geochemistry .20\nSulfur Isotopes .20\nCarbon and Oxygen Isotopes .20\nRadiogenic Isotope Geochemistry .23\nStrontium Isotopes .23\nLead Isotopes .23\nPetrology of Associated Igneous Rocks .23\nPetrology of Associated Sedimentary Rocks .24\nFracture Density and Permeability .24\nSecondary Porosity .24\nHydrothermal Cement .24\nOrganic Matter .24\nFacies Transition .24\nEnvironment of Deposition .24\nPetrology of Associated Metamorphic Rocks .24\nTheory of Deposit Formation .24\nOre Deposit System Affiliation .24\nSources of Metals.24\nSources of Sulfur .24\nSources of Ligands Involved in Ore Component Transport .25\nSources of Fluids Involved in Ore Component Transport .25\nChemical Transport and Transfer Processes .25\nFluid-Drive Mechanisms .25\nNature of Traps and Geological Controls that Trigger Ore Precipitation .25',
#        'page': 5,
#        'bounding_box': []}]}]},
#   {'criteria': 'The mappable proxy that represents the geological features related to the source of MVT Lead-Zinc deposits could be:\n- Temporal and spatial connection with orogenic forelands',
#    'theoretical': 'N/A',
#    'potential_dataset': [{'name': 'Geology:Black shale:Proximity to black shale (pixels; calculated from raster with 0.01 degree grid):Geology_BlackShale_Proximity',
#      'relevance_score': 0.9837963133353468},
#     {'name': 'Geology:Fault:Proximity to fault (pixels; calculated from raster with 0.01 degree grid):Geology_Fault_Proximity',
#      'relevance_score': 0.9829173674160856},
#     {'name': 'Geology:Geological terrane:Proximity to terrane boundary (pixels; calculated from raster with 0.01 degree grid):Terrane_Proximity',
#      'relevance_score': 0.9813290908436896},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Evaporitic',
#      'relevance_score': 0.9795339290939168},
#     {'name': 'Geology:Geochronology:Precense or absence of H3 cells with two or more geological periods:Geology_Period_Contact',
#      'relevance_score': 0.9788819284146841},
#     {'name': 'Geology:Passive margin:Proximity to passive margin (pixels; calculated from raster with 0.01 degree grid):Geology_PassiveMargin_Proximity',
#      'relevance_score': 0.9720561263794861},
#     {'name': 'Geology:Geological terrane:Precense or absence of H3 cells with two or more terrane names:Terrane_Contact',
#      'relevance_score': 0.9695236137198683},
#     {'name': 'Geology:Geochronology:Minimum Period name (raster value with the smallest sum of coverage fraction):Geology_Period_Minimum_Minority',
#      'relevance_score': 0.9691245371876964},
#     {'name': 'Geology:Geochronology:Maximum Era name (raster value with the largest sum of coverage fraction):Geology_Era_Maximum_Majority',
#      'relevance_score': 0.9661124574168398},
#     {'name': 'Geology:Geological terrane:Terrane name (raster value with the largest sum of coverage fractions):Terrane_Majority',
#      'relevance_score': 0.9643962076733431},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Calcareous',
#      'relevance_score': 0.9628890246740469},
#     {'name': 'Geology:Geochronology:Minimum Period name (raster value with the largest sum of coverage fraction):Geology_Period_Minimum_Majority',
#      'relevance_score': 0.9547005804369159},
#     {'name': 'Geology:Lithological contacts:Precense or absence of H3 cells with two or more lithologies:Geology_Lithology_Contact',
#      'relevance_score': 0.9449940384753368},
#     {'name': 'Geology:Geochronology:Maximum Period name (raster value with the largest sum of coverage fraction):Geology_Period_Maximum_Majority',
#      'relevance_score': 0.9436318974732343},
#     {'name': 'Geology:Geochronology:Maximum Period name (raster value with the smallest sum of coverage fraction):Geology_Period_Maximum_Minority',
#      'relevance_score': 0.9413522251765066},
#     {'name': 'Geology:Geological terrane:Terrane name (raster value with the smallest sum of coverage fractions):Terrane_Minority',
#      'relevance_score': 0.939553656497986},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Sedimentary',
#      'relevance_score': 0.9351918533439487},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) differential curvature deriverative:Gravity_GOCE_Differential',
#      'relevance_score': 0.9248997506672699},
#     {'name': 'Geology:Paleo-latitude:Calculated paleo-latitude based on maximum period (degrees):Geology_Paleolatitude_Period_Maximum',
#      'relevance_score': 0.9248492663922343},
#     {'name': 'Geology:Geochronology:Maximum Era name (raster value with the smallest sum of coverage fraction):Geology_Era_Maximum_Minority',
#      'relevance_score': 0.92443303456217},
#     {'name': 'Geology:Geochronology:Maximum Eon name (raster value with the largest sum of coverage fraction):Geology_Eon_Maximum_Majority',
#      'relevance_score': 0.9134753204537662},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Cherty',
#      'relevance_score': 0.9126998114903275},
#     {'name': 'Geophysics:Magnetic:Horizontal gradient magnitude (HGM):Magnetic_HGM',
#      'relevance_score': 0.904105895871238},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_RedBed',
#      'relevance_score': 0.9040602975361823},
#     {'name': 'Geology:Paleo-longitude:Calculated paleo-longitude based on maximum period (degrees):Geology_Paleolongitude_Period_Maximum',
#      'relevance_score': 0.8866705767640133},
#     {'name': 'Geology:Geochronology:Minimum Eon name (raster value with the largest sum of coverage fraction):Geology_Eon_Minimum_Majority',
#      'relevance_score': 0.8857544688295523},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Carbonaceous',
#      'relevance_score': 0.8842657812590946},
#     {'name': 'Geology:Paleo-latitude:Calculated paleo-latitude based on minimum period (degrees):Geology_Paleolatitude_Period_Minimum',
#      'relevance_score': 0.8841889843424918},
#     {'name': 'Geophysics:Gravity:Upward-continued (30 km) horizontal gradient magnitude (HGM):Gravity_Bouguer_UpCont30km_HGM',
#      'relevance_score': 0.8785953323975847},
#     {'name': 'Geophysics:Gravity:Bouguer gravity anomaly (mGal):Gravity_Bouguer',
#      'relevance_score': 0.8703986359802202},
#     {'name': 'Geophysics:Magnetic:Proximity to magnetic worms (pixels; calculated from raster with 0.01 degree grid):Magnetic_HGM_Worms_Proximity',
#      'relevance_score': 0.869137064028006},
#     {'name': 'Geology:Geochronology:Minimum Eera name (raster value with the smallest sum of coverage fraction):Geology_Era_Minimum_Minority',
#      'relevance_score': 0.8661410832544105},
#     {'name': 'Geology:Geochronology:Minimum Era name (raster value with the largest sum of coverage fraction):Geology_Era_Minimum_Majority',
#      'relevance_score': 0.8615890863025093},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Intermediate',
#      'relevance_score': 0.8598840021954051},
#     {'name': 'Geophysics:Gravity:Upward-continued (30 km) gravity anomaly (mGal):Gravity_Bouguer_UpCont30km',
#      'relevance_score': 0.8544684579336057},
#     {'name': 'Geophysics:Magnetic:Magnetic reduced-to-pole (RTP; nT):Magnetic_RTP',
#      'relevance_score': 0.8512952294065935},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) minimum curvature derivative:Gravity_GOCE_MinimumCurve',
#      'relevance_score': 0.8446002335169777},
#     {'name': 'Information:Geography:Province, state, or territory name (raster value with the largest sum of coverage fractions) :Province_Majority',
#      'relevance_score': 0.8429861588800065},
#     {'name': 'Geology:Geochronology:Minimum Eon name (raster value with the smallest sum of coverage fraction):Geology_Eon_Minimum_Minority',
#      'relevance_score': 0.8372248052725654},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) mean curvature derivative:Gravity_GOCE_MeanCurve',
#      'relevance_score': 0.8332429438974668},
#     {'name': 'Geophysics:Gravity:Horizontal gradient magnitude (HGM):Gravity_Bouguer_HGM',
#      'relevance_score': 0.8217408510461992},
#     {'name': 'Geology:Geochronology:Maximum Eon name (raster value with the smallest sum of coverage fraction):Geology_Eon_Maximum_Minority',
#      'relevance_score': 0.8175208025419425},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) shape index:Gravity_GOCE_ShapeIndex',
#      'relevance_score': 0.8169097788697002},
#     {'name': 'Geology:Lithology:Lithology sub-type (raster value with the largest sum of coverage fraction):Geology_Lithology_Majority',
#      'relevance_score': 0.8146496951850515},
#     {'name': 'Geophysics:Magnetic:Long-wavelength horizontal gradient magnitude (HGM):Magnetic_LongWavelength_HGM',
#      'relevance_score': 0.8099991829660906},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Schistose',
#      'relevance_score': 0.8013272448219093},
#     {'name': 'Geophysics:Magnetic:Upward-continued (4 km; nT):Magnetic_EMAG2v3',
#      'relevance_score': 0.792588331607661},
#     {'name': 'Geophysics:Magnetic:1st vertical derivative (1VD; nT/m):Magnetic_1VD',
#      'relevance_score': 0.7890302809305705},
#     {'name': 'Geophysics:Gravity:Bouguer gravity anomaly (mGal):Gravity_Bouguer_BGI',
#      'relevance_score': 0.7887051254452739},
#     {'name': 'Geophysics:Gravity:Proximity to gravity worms (pixels; calculated from raster with 0.01 degree grid):Gravity_Bouguer_HGM_Worms_Proximity',
#      'relevance_score': 0.7820732052238577},
#     {'name': 'Geology:Paleo-longitude:Calculated paleo-longitude based on minimum period (degrees):Geology_Paleolongitude_Period_Minimum',
#      'relevance_score': 0.7724145818352561},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) maximum curvature derivative:Gravity_GOCE_MaximumCurve',
#      'relevance_score': 0.7630936622416246},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_FineClastic',
#      'relevance_score': 0.7548573409280859},
#     {'name': 'Geophysics:Gravity:Proximity to upward-continued (30 km) worms (pixels; calculated from raster with 0.01 degree grid):Gravity_Bouguer_UpCont30km_HGM_Worms_Proximity',
#      'relevance_score': 0.7275375762991946},
#     {'name': 'Geophysics:Crustal models:Sediment thickness (m):Crust1_SedimentThickness',
#      'relevance_score': 0.7268132224002896},
#     {'name': 'Geology:Lithology:Lithology sub-type (raster value with the smallest sum of coverage fraction):Geology_Lithology_Minority',
#      'relevance_score': 0.7257564418417606},
#     {'name': 'Information:Geography:Continent name (raster value with the largest sum of coverage fractions) :Continent_Majority',
#      'relevance_score': 0.7116220764447683},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_UltramaficMafic',
#      'relevance_score': 0.7052906299881144},
#     {'name': 'Information:Geography:Country name (raster value with the largest sum of coverage fractions) :Country_Majority',
#      'relevance_score': 0.7016145498784598},
#     {'name': 'Information:Discrete Global Grid System (DGGS) cell ID:H3 cell address:H3_Address',
#      'relevance_score': 0.6852897893735803},
#     {'name': 'Information:Discrete Global Grid System (DGGS) cell coordinates:Latitude of central point calculated using the sf package (coordinates reported as decial degrees and are based on WGS84; EPSG4326):Latitude_EPSG4326',
#      'relevance_score': 0.6756396548629021},
#     {'name': 'Geophysics:Magnetotelluric:Global resistivity (ohm-m):Magnetotelluric',
#      'relevance_score': 0.6546110739062642},
#     {'name': 'Geophysics:Crustal models:Crustal thickness (km):Crust1_CrustalThickness',
#      'relevance_score': 0.639916083984152},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Gneissose',
#      'relevance_score': 0.6352490323764158},
#     {'name': 'Geophysics:Magnetic:Depth to Curie-point (km):Magnetic_EMAG2v3_CuriePoint',
#      'relevance_score': 0.5765325093324781},
#     {'name': 'Information:Discrete Global Grid System (DGGS) resolution:H3 cell resolution:H3_Resolution',
#      'relevance_score': 0.5737878214737723},
#     {'name': 'Information:Geography:Province, state, or territory name (raster value with the smallest sum of coverage fractions) :Province_Minority',
#      'relevance_score': 0.5735134157056023},
#     {'name': 'Geophysics:Magnetic:Proximity to long-wavlength worms (pixels; calculated from raster with 0.01 degree grid):Magnetic_LongWavelength_HGM_Worms_Proximity',
#      'relevance_score': 0.5618485777505687},
#     {'name': 'Geophysics:Lithospheric models:Crustal density  (kg m-3):Litmod_Density_Crust',
#      'relevance_score': 0.5080357296094989},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_CoarseClastic',
#      'relevance_score': 0.5064913669296809},
#     {'name': 'Geology:Cover thickness:Cover thickness (m):Geology_CoverThickness',
#      'relevance_score': 0.49731592044974765},
#     {'name': 'Geophysics:Seismic:Seismic velocity at 100 km depth (km s-1):Seismic_Velocity_100km',
#      'relevance_score': 0.4934461720094236},
#     {'name': 'Information:Discrete Global Grid System (DGGS) cell coordinates:Longitude of central point calculated using the sf package (coordinates reported as decimal degrees and are based on WGS84; EPSG4326):Longitude_EPSG4326',
#      'relevance_score': 0.48953934612840544},
#     {'name': 'Geophysics:Seismic:Depth to lithosphere-asthenosphere boundary (LAB; km):Seismic_LAB_Hoggard',
#      'relevance_score': 0.4749177727180672},
#     {'name': 'Information:Discrete Global Grid System (DGGS) geometry:H3 cell polygon geometry calculated using the sf package (Well Known Text, WKT, format; EPSG4326):H3_Geometry',
#      'relevance_score': 0.43301335868025037},
#     {'name': 'Information:Geography:Continent name (raster value with the smallest sum of coverage fractions):Continent_Minority',
#      'relevance_score': 0.42642746365845063},
#     {'name': 'Geophysics:Seismic:Seismic velocity at 50 km depth (km s–1):Seismic_Velocity_050km',
#      'relevance_score': 0.39128718504319343},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Anatectic',
#      'relevance_score': 0.38214685770553225},
#     {'name': 'Geophysics:Heat Flow:Global surface heat flow (mWm−2):HeatFlow',
#      'relevance_score': 0.35906799762614383},
#     {'name': 'Geophysics:Crustal models:Crust type name:Crust1_Type',
#      'relevance_score': 0.3551165974185226},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Pegmatitic',
#      'relevance_score': 0.3491621330651048},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Felsic',
#      'relevance_score': 0.2970907295888185},
#     {'name': 'Geophysics:Seismic:Depth to lithosphere-asthenosphere boundary (LAB; km):Seismic_LAB_Priestley',
#      'relevance_score': 0.26636311689362707},
#     {'name': 'Geophysics:Lithospheric models:Asthenospheric density (kg m-3):Litmod_Density_Asthenosphere',
#      'relevance_score': 0.2534337072531676},
#     {'name': 'Geophysics:Seismic:Depth to Mohorovičić discontinuity or Moho (km):Seismic_Moho_GEMMA',
#      'relevance_score': 0.23792589960177163},
#     {'name': 'Geophysics:Seismic:Seismic velocity at 150 km depth (km s–1):Seismic_Velocity_150km',
#      'relevance_score': 0.23653026708997466},
#     {'name': 'Geophysics:Lithospheric models:Lithospheric density  (kg m-3):Litmod_Density_Lithosphere',
#      'relevance_score': 0.19618578226431424},
#     {'name': 'Geophysics:Seismic:Depth to Mohorovičić discontinuity or Moho (km):Seismic_Moho',
#      'relevance_score': 0.164857271605578},
#     {'name': 'Geophysics:Seismic:Depth to Mohorovičić discontinuity or Moho (km):Seismic_Moho_Szwillus',
#      'relevance_score': 0.14850187419162517},
#     {'name': 'Information:Geography:Country name (raster with the smallest sum of coverage fractions):Country_Minority',
#      'relevance_score': 0.1349701008848416},
#     {'name': 'Geophysics:Seismic:Seismic velocity at 200 km depth (km s–1):Seismic_Velocity_200km',
#      'relevance_score': 0.09318089197853033},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Igneous',
#      'relevance_score': 0.08670254860092018},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Alkalic',
#      'relevance_score': 0.021629012375489504}],
#    'supporting_references': [{'document': {'id': 'SIR10-5070A',
#       'title': 'A Deposit Model for Mississippi Valley-Type Lead-Zinc Ores',
#       'doi': '10.3133/sir20105070A',
#       'uri': 'https://pubs.usgs.gov/sir/2010/5070/a/pdf/SIR10-5070A.pdf',
#       'authors': 'David L. Leach, Ryan D. Taylor, David L. Fey, Sharon F. Diehl, and Richard W. Saltus',
#       'journal': 'Scientific Investigations Report 2010-5070-A',
#       'year': 2010,
#       'month': nan,
#       'volume': nan,
#       'issue': nan,
#       'description': nan},
#      'page_info': [{'text': '6  A Deposit Model for Mississippi Valley-Type Lead-Zinc Ores\nore genesis to major crustal tectonic events (see Sharp, 1978; \nGarven, 1985; Oliver, 1986; Leach and Rowan 1986; Bethke \nand Marshak, 1990; Oliver, 1992; Leach and others, 2001). \nFurthermore, in the last 20 years, abundant evidence has \nshown that the ore fluids were derived mainly from evaporated \nseawater and were driven within platform carbonates by large-\nscale tectonic events.  Perhaps the most significant achieve-\nments in understanding MVT ore genesis have been from \nadvances in dating MVT ores (for example, Leach and others, \n2001, and references therein). \nRegional Environment\nGeotectonic Environment\nIt is generally recognized that most MVT deposits have \na temporal and spatial connection with orogenic forelands \n(Garven, 1985; Mitchell, 1985; Leach and Rowan, 1986; \nOliver, 1986; Leach and others, 2001).',
#        'page': 15,
#        'bounding_box': []}]}]},
#   {'criteria': 'The mappable proxy that represents the geological features related to the source of MVT Lead-Zinc deposits could be "carbonate platform sequences, especially those deposited in arid belts."',
#    'theoretical': 'N/A',
#    'potential_dataset': [{'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Calcareous',
#      'relevance_score': 0.9983025740597286},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Sedimentary',
#      'relevance_score': 0.996350430426824},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Evaporitic',
#      'relevance_score': 0.9910109651309423},
#     {'name': 'Geology:Passive margin:Proximity to passive margin (pixels; calculated from raster with 0.01 degree grid):Geology_PassiveMargin_Proximity',
#      'relevance_score': 0.9826371324162798},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_RedBed',
#      'relevance_score': 0.9819238789268402},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Intermediate',
#      'relevance_score': 0.9760951446966443},
#     {'name': 'Geology:Black shale:Proximity to black shale (pixels; calculated from raster with 0.01 degree grid):Geology_BlackShale_Proximity',
#      'relevance_score': 0.968767641402877},
#     {'name': 'Geology:Geological terrane:Terrane name (raster value with the smallest sum of coverage fractions):Terrane_Minority',
#      'relevance_score': 0.9647755484275432},
#     {'name': 'Geology:Paleo-latitude:Calculated paleo-latitude based on minimum period (degrees):Geology_Paleolatitude_Period_Minimum',
#      'relevance_score': 0.9549571801938386},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Cherty',
#      'relevance_score': 0.9534125184257446},
#     {'name': 'Geology:Geological terrane:Terrane name (raster value with the largest sum of coverage fractions):Terrane_Majority',
#      'relevance_score': 0.9492210785684045},
#     {'name': 'Information:Geography:Province, state, or territory name (raster value with the largest sum of coverage fractions) :Province_Majority',
#      'relevance_score': 0.9310752573589695},
#     {'name': 'Geology:Geological terrane:Proximity to terrane boundary (pixels; calculated from raster with 0.01 degree grid):Terrane_Proximity',
#      'relevance_score': 0.9133906908858515},
#     {'name': 'Geology:Geochronology:Maximum Era name (raster value with the smallest sum of coverage fraction):Geology_Era_Maximum_Minority',
#      'relevance_score': 0.9090239386526427},
#     {'name': 'Geology:Lithological contacts:Precense or absence of H3 cells with two or more lithologies:Geology_Lithology_Contact',
#      'relevance_score': 0.9087669121170111},
#     {'name': 'Geology:Geochronology:Maximum Era name (raster value with the largest sum of coverage fraction):Geology_Era_Maximum_Majority',
#      'relevance_score': 0.8897735071423584},
#     {'name': 'Geology:Paleo-latitude:Calculated paleo-latitude based on maximum period (degrees):Geology_Paleolatitude_Period_Maximum',
#      'relevance_score': 0.8865086553565238},
#     {'name': 'Geology:Geochronology:Precense or absence of H3 cells with two or more geological periods:Geology_Period_Contact',
#      'relevance_score': 0.8846103353268583},
#     {'name': 'Geology:Lithology:Lithology sub-type (raster value with the largest sum of coverage fraction):Geology_Lithology_Majority',
#      'relevance_score': 0.8770124329750582},
#     {'name': 'Geology:Geochronology:Minimum Period name (raster value with the smallest sum of coverage fraction):Geology_Period_Minimum_Minority',
#      'relevance_score': 0.8707478403128234},
#     {'name': 'Geology:Geological terrane:Precense or absence of H3 cells with two or more terrane names:Terrane_Contact',
#      'relevance_score': 0.8649260906812177},
#     {'name': 'Geology:Geochronology:Minimum Era name (raster value with the largest sum of coverage fraction):Geology_Era_Minimum_Majority',
#      'relevance_score': 0.8459453834750804},
#     {'name': 'Geology:Geochronology:Maximum Eon name (raster value with the largest sum of coverage fraction):Geology_Eon_Maximum_Majority',
#      'relevance_score': 0.8412265446140093},
#     {'name': 'Geology:Paleo-longitude:Calculated paleo-longitude based on minimum period (degrees):Geology_Paleolongitude_Period_Minimum',
#      'relevance_score': 0.8311680901771714},
#     {'name': 'Geology:Paleo-longitude:Calculated paleo-longitude based on maximum period (degrees):Geology_Paleolongitude_Period_Maximum',
#      'relevance_score': 0.8219891611185981},
#     {'name': 'Geology:Lithology:Lithology sub-type (raster value with the smallest sum of coverage fraction):Geology_Lithology_Minority',
#      'relevance_score': 0.8087377096547202},
#     {'name': 'Geophysics:Crustal models:Sediment thickness (m):Crust1_SedimentThickness',
#      'relevance_score': 0.80168357007503},
#     {'name': 'Geophysics:Gravity:Upward-continued (30 km) gravity anomaly (mGal):Gravity_Bouguer_UpCont30km',
#      'relevance_score': 0.8006100335212573},
#     {'name': 'Information:Geography:Country name (raster value with the largest sum of coverage fractions) :Country_Majority',
#      'relevance_score': 0.7959709410680806},
#     {'name': 'Geology:Geochronology:Maximum Eon name (raster value with the smallest sum of coverage fraction):Geology_Eon_Maximum_Minority',
#      'relevance_score': 0.7940996832184628},
#     {'name': 'Information:Discrete Global Grid System (DGGS) cell ID:H3 cell address:H3_Address',
#      'relevance_score': 0.7832751028988701},
#     {'name': 'Geophysics:Magnetic:1st vertical derivative (1VD; nT/m):Magnetic_1VD',
#      'relevance_score': 0.7732188753165914},
#     {'name': 'Geology:Geochronology:Minimum Eon name (raster value with the largest sum of coverage fraction):Geology_Eon_Minimum_Majority',
#      'relevance_score': 0.7658221012601615},
#     {'name': 'Geology:Cover thickness:Cover thickness (m):Geology_CoverThickness',
#      'relevance_score': 0.7630815825645622},
#     {'name': 'Geology:Geochronology:Minimum Period name (raster value with the largest sum of coverage fraction):Geology_Period_Minimum_Majority',
#      'relevance_score': 0.7381609195352221},
#     {'name': 'Geology:Geochronology:Maximum Period name (raster value with the smallest sum of coverage fraction):Geology_Period_Maximum_Minority',
#      'relevance_score': 0.734105006480263},
#     {'name': 'Geology:Geochronology:Maximum Period name (raster value with the largest sum of coverage fraction):Geology_Period_Maximum_Majority',
#      'relevance_score': 0.722510504500647},
#     {'name': 'Geophysics:Magnetic:Long-wavelength horizontal gradient magnitude (HGM):Magnetic_LongWavelength_HGM',
#      'relevance_score': 0.692762784984826},
#     {'name': 'Information:Geography:Province, state, or territory name (raster value with the smallest sum of coverage fractions) :Province_Minority',
#      'relevance_score': 0.6854990402868028},
#     {'name': 'Geology:Geochronology:Minimum Eon name (raster value with the smallest sum of coverage fraction):Geology_Eon_Minimum_Minority',
#      'relevance_score': 0.6848206498764114},
#     {'name': 'Geophysics:Magnetic:Upward-continued (4 km; nT):Magnetic_EMAG2v3',
#      'relevance_score': 0.6799157945662234},
#     {'name': 'Geology:Geochronology:Minimum Eera name (raster value with the smallest sum of coverage fraction):Geology_Era_Minimum_Minority',
#      'relevance_score': 0.6754005882943706},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) minimum curvature derivative:Gravity_GOCE_MinimumCurve',
#      'relevance_score': 0.6701949759844478},
#     {'name': 'Information:Geography:Continent name (raster value with the smallest sum of coverage fractions):Continent_Minority',
#      'relevance_score': 0.6690939735728205},
#     {'name': 'Geophysics:Gravity:Horizontal gradient magnitude (HGM):Gravity_Bouguer_HGM',
#      'relevance_score': 0.6627231153048756},
#     {'name': 'Information:Discrete Global Grid System (DGGS) resolution:H3 cell resolution:H3_Resolution',
#      'relevance_score': 0.6372957343498974},
#     {'name': 'Geophysics:Gravity:Bouguer gravity anomaly (mGal):Gravity_Bouguer',
#      'relevance_score': 0.6132989122215416},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) differential curvature deriverative:Gravity_GOCE_Differential',
#      'relevance_score': 0.6087661835814402},
#     {'name': 'Geophysics:Gravity:Bouguer gravity anomaly (mGal):Gravity_Bouguer_BGI',
#      'relevance_score': 0.6036779793452433},
#     {'name': 'Geophysics:Gravity:Upward-continued (30 km) horizontal gradient magnitude (HGM):Gravity_Bouguer_UpCont30km_HGM',
#      'relevance_score': 0.5970167374815738},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Carbonaceous',
#      'relevance_score': 0.570540369825705},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_UltramaficMafic',
#      'relevance_score': 0.5567474795119698},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_FineClastic',
#      'relevance_score': 0.5468269984420717},
#     {'name': 'Information:Geography:Continent name (raster value with the largest sum of coverage fractions) :Continent_Majority',
#      'relevance_score': 0.5394881280468157},
#     {'name': 'Geophysics:Magnetic:Horizontal gradient magnitude (HGM):Magnetic_HGM',
#      'relevance_score': 0.5275810374149018},
#     {'name': 'Geology:Fault:Proximity to fault (pixels; calculated from raster with 0.01 degree grid):Geology_Fault_Proximity',
#      'relevance_score': 0.501685590124646},
#     {'name': 'Geophysics:Magnetic:Magnetic reduced-to-pole (RTP; nT):Magnetic_RTP',
#      'relevance_score': 0.49192733819111206},
#     {'name': 'Geophysics:Gravity:Proximity to gravity worms (pixels; calculated from raster with 0.01 degree grid):Gravity_Bouguer_HGM_Worms_Proximity',
#      'relevance_score': 0.48475484018474674},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) shape index:Gravity_GOCE_ShapeIndex',
#      'relevance_score': 0.4648073315547954},
#     {'name': 'Geophysics:Magnetic:Proximity to magnetic worms (pixels; calculated from raster with 0.01 degree grid):Magnetic_HGM_Worms_Proximity',
#      'relevance_score': 0.44084395927182296},
#     {'name': 'Information:Discrete Global Grid System (DGGS) cell coordinates:Longitude of central point calculated using the sf package (coordinates reported as decimal degrees and are based on WGS84; EPSG4326):Longitude_EPSG4326',
#      'relevance_score': 0.4381139949610242},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) mean curvature derivative:Gravity_GOCE_MeanCurve',
#      'relevance_score': 0.42223548468548333},
#     {'name': 'Geophysics:Magnetic:Depth to Curie-point (km):Magnetic_EMAG2v3_CuriePoint',
#      'relevance_score': 0.3618864465242633},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Anatectic',
#      'relevance_score': 0.3565048623822151},
#     {'name': 'Information:Discrete Global Grid System (DGGS) cell coordinates:Latitude of central point calculated using the sf package (coordinates reported as decial degrees and are based on WGS84; EPSG4326):Latitude_EPSG4326',
#      'relevance_score': 0.3380999219896201},
#     {'name': 'Geophysics:Gravity:Gravity field and steady-state Ocean Circulation Explorer (GOCE) maximum curvature derivative:Gravity_GOCE_MaximumCurve',
#      'relevance_score': 0.33513491395715655},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_CoarseClastic',
#      'relevance_score': 0.31563301033353336},
#     {'name': 'Geophysics:Magnetic:Proximity to long-wavlength worms (pixels; calculated from raster with 0.01 degree grid):Magnetic_LongWavelength_HGM_Worms_Proximity',
#      'relevance_score': 0.28265678251144144},
#     {'name': 'Geophysics:Magnetotelluric:Global resistivity (ohm-m):Magnetotelluric',
#      'relevance_score': 0.2745870352450776},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Schistose',
#      'relevance_score': 0.23579351343845692},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Felsic',
#      'relevance_score': 0.20544866122081293},
#     {'name': 'Information:Geography:Country name (raster with the smallest sum of coverage fractions):Country_Minority',
#      'relevance_score': 0.19443359268631263},
# ...
#       'journal': 'Scientific Investigations Report 2010-5070-A',
#       'year': 2010,
#       'month': nan,
#       'volume': nan,
#       'issue': nan,
#       'description': nan},
#      'page_info': [{'text': 'Consequently, hydrothermal dissolu-\ntion features and replacement halos are common in and about \nMVT deposits. The most significant acid production occurs as \na consequence of the mixing of reduced sulfur-bearing fluids \nwith a metal-bearing fluid and, to a lesser extent, by sulfate \nreduction in the ore zone.\nDolomite and Calcite Alteration\nDolomite or calcite alteration of the host-rocks is present \nin most MVT deposits. As discussed above, carbonate flood-\ning of porosity about the deposits often forms envelopes that \nextend for meters to hundreds of meters. In many examples, \nthe hydrothermal alteration produces a coarsely crystalline \ndolomite by recrystallization of the host carbonate rocks [for \nexample, gray coarse-grained early dolomite halos in Tri-State \ndistrict (McKnight and Fischer, 1970)].\nSilicification\n Silicification of the host carbonate rocks is generally \nminor in most MVT deposits but is well developed in the Tri-\nState (Brockie and others, 1968) and the Northern Arkansas \ndistricts (McKnight, 1935).',
#        'page': 25,
#        'bounding_box': []}]}]},
#   {'criteria': 'The paragraph suggests that ore-stage calcite and Paleozoic fluid flow can be used as mappable proxies for the preservation of Mississippi Valley-Type lead-zinc mineralization.',
#    'theoretical': 'N/A',
#    'potential_dataset': [{'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Calcareous',
#      'relevance_score': 0.9988252274861371},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Cherty',
#      'relevance_score': 0.9909766579161846},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Sedimentary',
#      'relevance_score': 0.9833176279698626},
#     {'name': 'Geology:Geological terrane:Precense or absence of H3 cells with two or more terrane names:Terrane_Contact',
#      'relevance_score': 0.9766849848460047},
#     {'name': 'Geology:Geological terrane:Proximity to terrane boundary (pixels; calculated from raster with 0.01 degree grid):Terrane_Proximity',
#      'relevance_score': 0.9685934707020069}],
#    'supporting_references': [{'document': {'id': 'SIR10-5070A',
#       'title': 'A Deposit Model for Mississippi Valley-Type Lead-Zinc Ores',
#       'doi': '10.3133/sir20105070A',
#       'uri': 'https://pubs.usgs.gov/sir/2010/5070/a/pdf/SIR10-5070A.pdf',
#       'authors': 'David L. Leach, Ryan D. Taylor, David L. Fey, Sharon F. Diehl, and Richard W. Saltus',
#       'journal': 'Scientific Investigations Report 2010-5070-A',
#       'year': 2010,
#       'month': nan,
#       'volume': nan,
#       'issue': nan,
#       'description': nan},
#      'page_info': [{'text': '35–43.\nBradley, D.C., and Leach, D.L., 2003, Tectonic controls of \nMississippi Valley-Type lead-zinc mineralization in oro-\ngenic forelands: Mineralium Deposita, v. 38, p. 652–667.\nBrannon, J.C., Cole, S.C., Podosek, F.A., Ragan, V.M., Cove-\nnay, R.M., Jr., Wallace, M.W., and Bradley, A.J., 1996a, \nTh-Pb and U-Pb dating of ore-stage calcite and Paleozoic \nfluid flow: Science, v. 271, p. 491–493.\nBrannon, J.C., Podosek, F.A., and Cole, S.C., 1996b, Radio-\nmetric dating of Mississippi Valley-Type ore deposits, in \nSangster, D.F., ed., Carbonate-hosted lead-zinc deposits: \nSociety of Economic Geologists Special Publication 4,  \np. 536–545.',
#        'page': 43,
#        'bounding_box': []}]}]},
#   {'criteria': 'The paragraph mentions conodont color and surface textural alteration in the Muschelkalk (Triassic) of the Silesian-Cracow Zn-Pb district, Poland, as a mappable proxy for the preservation of carbonate-hosted zinc-lead deposits.',
#    'theoretical': 'N/A',
#    'potential_dataset': [{'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Calcareous',
#      'relevance_score': 0.9958990395988637},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Sedimentary',
#      'relevance_score': 0.9741868860018312},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Evaporitic',
#      'relevance_score': 0.971957924509789},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Carbonaceous',
#      'relevance_score': 0.9473555826588316},
#     {'name': 'Geology:Black shale:Proximity to black shale (pixels; calculated from raster with 0.01 degree grid):Geology_BlackShale_Proximity',
#      'relevance_score': 0.9329178792140275}],
#    'supporting_references': [{'document': {'id': 'SIR10-5070A',
#       'title': 'A Deposit Model for Mississippi Valley-Type Lead-Zinc Ores',
#       'doi': '10.3133/sir20105070A',
#       'uri': 'https://pubs.usgs.gov/sir/2010/5070/a/pdf/SIR10-5070A.pdf',
#       'authors': 'David L. Leach, Ryan D. Taylor, David L. Fey, Sharon F. Diehl, and Richard W. Saltus',
#       'journal': 'Scientific Investigations Report 2010-5070-A',
#       'year': 2010,
#       'month': nan,
#       'volume': nan,
#       'issue': nan,
#       'description': nan},
#      'page_info': [{'text': '82, p. 1294–1308.\nReichert, Jörg, and Borg, Gregor, 2008, Numerical simulation \nand a geochemical model of supergene carbonate-hosted \nnon-sulphide zinc deposits: Ore Geology Reviews, v. 33,  \np. 134–151. \nRepetski, J.E., and Narkiewicz, Marek, 1996, Conodont color \nand surface textural alteration in the Muschelkalk (Triassic) \nof the Silesian-Cracow Zn-Pb district, Poland, in Gorecka, \nEwa, and Leach, D.L., eds., Carbonate-hosted zinc-lead \ndeposits in the Silesian-Cracow area, Poland: Wydawnictwa \nGeologiczne, Warsaw, Poland, v. 154, p. 113–122.',
#        'page': 49,
#        'bounding_box': [[391.6300048828125,
#          458.1266784667969,
#          464.1300048828125,
#          469.2008972167969],
#         [306.0, 479.0193786621094, 556.0301513671875, 490.0935974121094],
#         [316.0, 491.91217041015625, 544.9000244140625, 502.98638916015625],
#         [316.0, 504.80487060546875, 548.646484375, 515.8790893554688],
#         [316.0, 517.6976318359375, 366.0, 528.7718505859375],
#         [306.0, 538.59033203125, 555.130126953125, 549.66455078125],
#         [316.0, 551.483154296875, 557.2201538085938, 562.557373046875],
#         [316.0, 564.3758544921875, 552.3406982421875, 575.4500732421875],
#         [316.0, 577.2685546875, 541.4900512695312, 588.3427734375],
#         [316.0, 590.161376953125, 559.0499877929688, 601.235595703125],
#         [316.0, 603.05419921875, 516.9200439453125, 614.12841796875]]}]}]},
#   {'criteria': 'The mappable proxy that represents the geological features related to preservation of the MVT Lead-Zinc deposit type in the Southeast Missouri region could be the presence of post-sulfide barite deposits in the overlying Upper Cambrian-Ordovician lead-zinc bearing deposits.',
#    'theoretical': 'N/A',
#    'potential_dataset': [{'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Evaporitic',
#      'relevance_score': 0.9940830882800834},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Sedimentary',
#      'relevance_score': 0.9907041936450991},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Intermediate',
#      'relevance_score': 0.9905007714448183},
#     {'name': 'Geology:Geochronology:Precense or absence of H3 cells with two or more geological periods:Geology_Period_Contact',
#      'relevance_score': 0.9595515874979907},
#     {'name': 'Geology:Lithological contacts:Precense or absence of H3 cells with two or more lithologies:Geology_Lithology_Contact',
#      'relevance_score': 0.952060577868885}],
#    'supporting_references': [{'document': {'id': 'SIR10-5070A',
#       'title': 'A Deposit Model for Mississippi Valley-Type Lead-Zinc Ores',
#       'doi': '10.3133/sir20105070A',
#       'uri': 'https://pubs.usgs.gov/sir/2010/5070/a/pdf/SIR10-5070A.pdf',
#       'authors': 'David L. Leach, Ryan D. Taylor, David L. Fey, Sharon F. Diehl, and Richard W. Saltus',
#       'journal': 'Scientific Investigations Report 2010-5070-A',
#       'year': 2010,
#       'month': nan,
#       'volume': nan,
#       'issue': nan,
#       'description': nan},
#      'page_info': [{'text': 'Barite has never been reported in the Cambrian-hosted \nSoutheast Missouri Lead districts. However, large deposits of \npost-sulfide barite are present in the overlying Upper Cambrian-\nOrdovician lead-zinc bearing deposits of the Southeast Missouri \nBarite district.\nOrganic matter occurs as degraded liquid hydrocarbons \nand bitumen in variable amounts and types in MVT depos-\nits (Leventhal, 1990). However, its relation to ore genesis \nis usually equivocal. Studies of organic material from the \nViburnum Trend district (for example, Leventhal, 1990) show \nthat organic matter in the ore was thermally and composition-\nally altered by the ore fluids. Some districts contain abundant \nliquid hydrocarbons generally as late infilling of vugs and \ncoatings on ore stage minerals (Tri-State district and Pine \nPoint district). Liquid or solid petroleum-type organic matter \nhas infrequently been observed in primary fluid inclusions \nin main-stage minerals.',
#        'page': 24,
#        'bounding_box': []}]}]},
#   {'criteria': 'The mappable proxy that represents the geological features related to preservation of the MVT Lead-Zinc deposit type is the presence of white, efflorescent minerals and evaporative mineral crusts containing Mg-sulfate minerals, remnant etched dolomite rhombs, and sulfide minerals such as pyrite, galena, sphalerite, and nickel and copper sulfides.',
#    'theoretical': 'N/A',
#    'potential_dataset': [{'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Evaporitic',
#      'relevance_score': 0.9994839160771439},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Cherty',
#      'relevance_score': 0.9829470844060694},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Sedimentary',
#      'relevance_score': 0.9787047912868686},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Intermediate',
#      'relevance_score': 0.9653909839356974},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Calcareous',
#      'relevance_score': 0.9449123992420443}],
#    'supporting_references': [{'document': {'id': 'SIR10-5070A',
#       'title': 'A Deposit Model for Mississippi Valley-Type Lead-Zinc Ores',
#       'doi': '10.3133/sir20105070A',
#       'uri': 'https://pubs.usgs.gov/sir/2010/5070/a/pdf/SIR10-5070A.pdf',
#       'authors': 'David L. Leach, Ryan D. Taylor, David L. Fey, Sharon F. Diehl, and Richard W. Saltus',
#       'journal': 'Scientific Investigations Report 2010-5070-A',
#       'year': 2010,
#       'month': nan,
#       'volume': nan,
#       'issue': nan,
#       'description': nan},
#      'page_info': [{'text': '(A) White, efflorescent minerals formed at the top of drying tailings, Upper Fletcher/St. Joe \ntailings, Missouri (Photography by Philip Hageman, U.S. Geological Survey, date unknown).  \n(B) Evaporative mineral crusts (arrow in A) contain Mg-sulfate minerals, remnant etched dolomite \nrhombs, and sulfide minerals consisting of etched pyrite grains from ≤ 20 microns and grains of galena, \nsphalerite, and nickel, copper sulfides ≤ 5 microns. Magnesium-sulfate minerals are poorly ordered, \ncommonly have curved crystal faces, and are susceptible to rapid dissolution.',
#        'page': 38,
#        'bounding_box': [[157.58999633789062,
#          399.6195068359375,
#          503.2190246582031,
#          411.15252685546875],
#         [111.16439819335938,
#          411.6195068359375,
#          459.5804138183594,
#          423.15252685546875],
#         [111.16439819335938,
#          423.6195068359375,
#          484.739501953125,
#          435.15252685546875],
#         [111.16429901123047,
#          435.6195068359375,
#          503.1108703613281,
#          447.15252685546875],
#         [111.16429901123047,
#          447.6195068359375,
#          491.4944763183594,
#          459.15252685546875],
#         [111.16429901123047,
#          459.6195068359375,
#          406.101318359375,
#          471.15252685546875]]}]}]},
#   {'criteria': 'The mappable proxy that represents the geological features related to the preservation of MVT Lead-Zinc deposits in the Ozark region can be summarized as follows:\n1. Regional geochemical halos of trace elements in trace sulfides from insoluble residues of barren carbonate rocks extending for several hundred kilometers from the MVT districts.\n2. Systematic change of increasing Zn/Pb from insoluble residues of barren carbonate from the lower-most to upper-most carbonates in the stratigraphic section in the region.\n3. Fluid inclusion temperatures ranging from about 50°C to 250°C, with most temperatures between 75°C and 200°C, recorded in MVT deposits.',
#    'theoretical': 'N/A',
#    'potential_dataset': [{'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Calcareous',
#      'relevance_score': 0.9965614756117696},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Cherty',
#      'relevance_score': 0.9912422494793405},
#     {'name': 'Geology:Geological properties:Precense or absence of geological property:Geology_Dictionary_Sedimentary',
#      'relevance_score': 0.9770594912819411},
#     {'name': 'Geology:Black shale:Proximity to black shale (pixels; calculated from raster with 0.01 degree grid):Geology_BlackShale_Proximity',
#      'relevance_score': 0.9730122577328465},
#     {'name': 'Geology:Geological terrane:Proximity to terrane boundary (pixels; calculated from raster with 0.01 degree grid):Terrane_Proximity',
#      'relevance_score': 0.9695874831915997}],
#    'supporting_references': [{'document': {'id': 'SIR10-5070A',
#       'title': 'A Deposit Model for Mississippi Valley-Type Lead-Zinc Ores',
#       'doi': '10.3133/sir20105070A',
#       'uri': 'https://pubs.usgs.gov/sir/2010/5070/a/pdf/SIR10-5070A.pdf',
#       'authors': 'David L. Leach, Ryan D. Taylor, David L. Fey, Sharon F. Diehl, and Richard W. Saltus',
#       'journal': 'Scientific Investigations Report 2010-5070-A',
#       'year': 2010,
#       'month': nan,
#       'volume': nan,
#       'issue': nan,
#       'description': nan},
#      'page_info': [{'text': 'In the Ozark region, \nErickson and others (1983) identified regional geochemical \nhalos of trace elements in trace sulfides from insoluble resi-\ndues of barren carbonate rocks that extend for several hundred \nkilometers from the MVT districts. Erickson and others (1983) \nalso described a systematic change of increasing Zn/Pb from \ninsoluble residues of barren carbonate from the lower-most to \nupper-most carbonates in the stratigraphic section in the region. \nFluid Inclusion Thermometry and Geochemistry\nTemperature of the Ore Fluids   \nFluid inclusion temperatures in MVT deposits range from \nabout 50°C to 250°C; however, most of the temperatures are \nbetween 75°C and 200°C (fig. 8). These ranges are similar to \nvalues determined by Basuki and Spooner (2004). The highest \nfluid inclusion temperatures (~180°C to ~ 250°C) recorded \nare for the Irish Midlands district and Gays River deposit, ores \nthat were relatively near each other during ore deposition but \ndrifted apart during the opening of the Atlantic (Leach and \nothers, 2001).',
#        'page': 28,
#        'bounding_box': []}]}]}]}

# %%
doc_meta
# Out:
# {'id': 'SIR10-5070A',
#  'title': 'A Deposit Model for Mississippi Valley-Type Lead-Zinc Ores',
#  'doi': '10.3133/sir20105070A',
#  'uri': 'https://pubs.usgs.gov/sir/2010/5070/a/pdf/SIR10-5070A.pdf',
#  'authors': 'David L. Leach, Ryan D. Taylor, David L. Fey, Sharon F. Diehl, and Richard W. Saltus',
#  'journal': 'Scientific Investigations Report 2010-5070-A',
#  'year': 2010,
#  'month': nan,
#  'volume': nan,
#  'issue': nan,
#  'description': nan}

# %%
print({k: doc_meta[k] for k in doc_meta if doc_meta[k] is np.nan})
# Out:
# {}

# %%
import math
math.isnan(doc_meta['month'])
# Out:
# True
