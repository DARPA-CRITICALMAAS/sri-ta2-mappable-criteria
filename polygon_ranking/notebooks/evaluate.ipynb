# %%
import geopandas as gpd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
data_fname = '../labels/regional_por_cu.gpkg'
data = gpd.read_file(data_fname)
data
# Out:
#     STATE ORIG_LABEL SGMC_LABEL  UNIT_LINK  \
# 0      AZ         ?m      TRm;0    AZTRm;0
# 1      AZ         ?¬     MZPZ;0   AZMZPZ;0
# 2      AZ         J?      JTR;0    AZJTR;0
# 3      AZ         Jg       Jg;0     AZJg;0
# 4      AZ        Jsv      Jsv;0    AZJsv;0
# ..    ...        ...        ...        ...
# 196    NV         br       br;0     NVbr;0
# 197    NV      lPMbc    PAMbc;0  NVPAMbc;0
# 198    TX          K        K;0      TXK;0
# 199    TX        QTb      QTb;0    TXQTb;0
# 200    TX        Qal      Qal;0    TXQal;0
#
#                                              UNIT_NAME  \
# 0                                   Moenkopi Formation
# 1    Jurassic to Cambrian metamorphosed sedimentary...
# 2    Jurassic and Triassic sedimentary and volcanic...
# 3                              Jurassic granitic rocks
# 4              Jurassic sedimentary and volcanic rocks
# ..                                                 ...
# ...

# %%
label_pos_fname = '../labels/regional_PorCu_pos.gpkg'
label_pos = gpd.read_file(label_pos_fname)

label_neg_fname = '../labels/regional_PorCu_neg_rand_4km.gpkg'
label_neg = gpd.read_file(label_neg_fname)

# %%
label_pos.keys()
# label_pos = label_pos[['OBJECTID', 'Name', 'Dep_type', 'SiteStatus', 'Age_range', '']]
# Out:
# Index(['OBJECTID', 'GMRAP_ID', 'Coded_ID', 'Tract_name', 'Name', 'Name_other',
#        'Name_group', 'Includes', 'SiteStatus', 'Country', 'State_Prov',
#        'Latitude', 'Longitude', 'Dep_type', 'Dep_subtype', 'Age_Ma',
#        'Age_method', 'Age_range', 'Age_ref', 'Comm_major', 'Comm_minor',
#        'Comm_trace', 'Tonnage_Mt', 'Cu_pct', 'Mo_pct', 'Au_g_t', 'Ag_g_t',
#        'Con_Cu_t', 'Au_Mo', 'Comments', 'Assd_rock', 'Dev_Status', 'Ref_list',
#        'Setting', 'Study_area', 'Short_ref', 'Strat_age', 'STATEFP', 'STATENS',
#        'AFFGEOID', 'GEOID', 'STUSPS', 'NAME_2', 'LSAD', 'ALAND', 'AWATER',
#        'SiteStatus2', 'Age_host', 'Unit', 'Host_rocks', 'Co_pct', 'layer',
#        'path', 'OBJECTID_2', 'AREA', 'PERIMETER', 'REGIONS_', 'REGIONS_ID',
#        'REGION', 'NAME_3', 'WORDS', 'AREA_SQKM', 'Shape_Leng', 'Shape_Le_1',
#        'Shape_Area', 'geometry'],
#       dtype='object')

# %%
label_neg
# Out:
#     id                     geometry
# 0    0  POINT (-114.62854 35.54100)
# 1    1  POINT (-111.01708 34.00317)
# 2    2  POINT (-110.22761 33.50591)
# 3    3  POINT (-115.39460 36.31889)
# 4    4  POINT (-112.19634 33.29808)
# ..  ..                          ...
# 58  58  POINT (-107.43388 32.90690)
# 59  59  POINT (-113.97664 35.83694)
# 60  60  POINT (-113.92970 35.18768)
# 61  61  POINT (-116.21807 36.05816)
# 62  62  POINT (-116.37408 35.20329)
#
# [63 rows x 2 columns]

# %%
buffer = True
    
data = data.to_crs("EPSG:32634")

label_pos = label_pos.to_crs("EPSG:32634")
label_neg = label_neg.to_crs("EPSG:32634")
if buffer:
    label_pos_buf = label_pos.copy()
    label_pos_buf.geometry = label_pos_buf.geometry.buffer(2000)

    label_neg_buf = label_neg.copy()
    label_neg_buf.geometry = label_neg_buf.geometry.buffer(2000)

# %%
data["tempid"] = range(data.shape[0])
matches = gpd.sjoin(left_df = data, right_df=label, how="inner").tempid

# %%
data_filtered = data.loc[data.tempid.isin(matches)]
data_filtered.head()
# Out:
#     STATE ORIG_LABEL SGMC_LABEL UNIT_LINK  \
# 259    AZ         Jg       Jg;0    AZJg;0
# 263    AZ        Jsv      Jsv;0   AZJsv;0
# 268    AZ        KJs      KJs;0   AZKJs;0
# 271    AZ         Kv       Kv;0    AZKv;0
# 272    AZ         M?      MCA;0   AZMCA;0
#
#                                              UNIT_NAME  \
# 259                            Jurassic granitic rocks
# 263            Jurassic sedimentary and volcanic rocks
# 268  Cretaceous to Late Jurassic sedimentary rocks ...
# 271   Early Tertiary to Late Cretaceous volcanic rocks
# 272  Mississippian, Devonian, and Cambrian sediment...
#
#                                                AGE_MIN  \
# 259  Phanerozoic - Mesozoic - Jurassic - Late-Juras...
# 263  Phanerozoic - Mesozoic - Jurassic - Late-Juras...
# 268  Phanerozoic - Mesozoic - Cretaceous - Late-Cre...
# 271  Phanerozoic - Cenozoic - Tertiary-Paleogene - ...
# 272  Phanerozoic - Paleozoic - Carboniferous - Late...
#
# ...

# %%
rank_attr = "bge_rock_types"

assert rank_attr in data

gt = data_filtered["tempid"].tolist()
rankings = np.argsort(data[rank_attr])[::-1]
ranked_list = [int(e in gt) for e in rankings]

# %%
def mean_reciprocal_rank(rs):
    """Score is reciprocal of the rank of the first relevant item

    First element is 'rank 1'.  Relevance is binary (nonzero is relevant).

    Example from http://en.wikipedia.org/wiki/Mean_reciprocal_rank
    >>> rs = [[0, 0, 1], [0, 1, 0], [1, 0, 0]]
    >>> mean_reciprocal_rank(rs)
    0.61111111111111105
    >>> rs = np.array([[0, 0, 0], [0, 1, 0], [1, 0, 0]])
    >>> mean_reciprocal_rank(rs)
    0.5
    >>> rs = [[0, 0, 0, 1], [1, 0, 0], [1, 0, 0]]
    >>> mean_reciprocal_rank(rs)
    0.75

    Args:
        rs: Iterator of relevance scores (list or numpy) in rank order
            (first element is the first item)

    Returns:
        Mean reciprocal rank
    """
    rs = (np.asarray(r).nonzero()[0] for r in rs)
    return np.mean([1. / (r[0] + 1) if r.size else 0. for r in rs])

def r_precision(r):
    """Score is precision after all relevant documents have been retrieved

    Relevance is binary (nonzero is relevant).

    >>> r = [0, 0, 1]
    >>> r_precision(r)
    0.33333333333333331
    >>> r = [0, 1, 0]
    >>> r_precision(r)
    0.5
    >>> r = [1, 0, 0]
    >>> r_precision(r)
    1.0

    Args:
        r: Relevance scores (list or numpy) in rank order
            (first element is the first item)

    Returns:
        R Precision
    """
    r = np.asarray(r) != 0
    z = r.nonzero()[0]
    if not z.size:
        return 0.
    return np.mean(r[:z[-1] + 1])

def precision_at_k(r, k):
    """Score is precision @ k

    Relevance is binary (nonzero is relevant).

    >>> r = [0, 0, 1]
    >>> precision_at_k(r, 1)
    0.0
    >>> precision_at_k(r, 2)
    0.0
    >>> precision_at_k(r, 3)
    0.33333333333333331
    >>> precision_at_k(r, 4)
    Traceback (most recent call last):
        File "<stdin>", line 1, in ?
    ValueError: Relevance score length < k


    Args:
        r: Relevance scores (list or numpy) in rank order
            (first element is the first item)

    Returns:
        Precision @ k

    Raises:
        ValueError: len(r) must be >= k
    """
    assert k >= 1
    r = np.asarray(r)[:k] != 0
    if r.size != k:
        raise ValueError('Relevance score length < k')
    return np.mean(r)

def average_precision(r):
    """Score is average precision (area under PR curve)

    Relevance is binary (nonzero is relevant).

    >>> r = [1, 1, 0, 1, 0, 1, 0, 0, 0, 1]
    >>> delta_r = 1. / sum(r)
    >>> sum([sum(r[:x + 1]) / (x + 1.) * delta_r for x, y in enumerate(r) if y])
    0.7833333333333333
    >>> average_precision(r)
    0.78333333333333333

    Args:
        r: Relevance scores (list or numpy) in rank order
            (first element is the first item)

    Returns:
        Average precision
    """
    r = np.asarray(r) != 0
    out = [precision_at_k(r, k + 1) for k in range(r.size) if r[k]]
    if not out:
        return 0.
    return np.mean(out)

def mean_average_precision(rs):
    """Score is mean average precision

    Relevance is binary (nonzero is relevant).

    >>> rs = [[1, 1, 0, 1, 0, 1, 0, 0, 0, 1]]
    >>> mean_average_precision(rs)
    0.78333333333333333
    >>> rs = [[1, 1, 0, 1, 0, 1, 0, 0, 0, 1], [0]]
    >>> mean_average_precision(rs)
    0.39166666666666666

    Args:
        rs: Iterator of relevance scores (list or numpy) in rank order
            (first element is the first item)

    Returns:
        Mean average precision
    """
    return np.mean([average_precision(r) for r in rs])

def dcg_at_k(r, k, method=0):
    """Score is discounted cumulative gain (dcg)

    Relevance is positive real values.  Can use binary
    as the previous methods.

    Example from
    http://www.stanford.edu/class/cs276/handouts/EvaluationNew-handout-6-per.pdf
    >>> r = [3, 2, 3, 0, 0, 1, 2, 2, 3, 0]
    >>> dcg_at_k(r, 1)
    3.0
    >>> dcg_at_k(r, 1, method=1)
    3.0
    >>> dcg_at_k(r, 2)
    5.0
    >>> dcg_at_k(r, 2, method=1)
    4.2618595071429155
    >>> dcg_at_k(r, 10)
    9.6051177391888114
    >>> dcg_at_k(r, 11)
    9.6051177391888114

    Args:
        r: Relevance scores (list or numpy) in rank order
            (first element is the first item)
        k: Number of results to consider
        method: If 0 then weights are [1.0, 1.0, 0.6309, 0.5, 0.4307, ...]
                If 1 then weights are [1.0, 0.6309, 0.5, 0.4307, ...]

    Returns:
        Discounted cumulative gain
    """
    r = np.asfarray(r)[:k]
    if r.size:
        if method == 0:
            return r[0] + np.sum(r[1:] / np.log2(np.arange(2, r.size + 1)))
        elif method == 1:
            return np.sum(r / np.log2(np.arange(2, r.size + 2)))
        else:
            raise ValueError('method must be 0 or 1.')
    return 0.

def ndcg_at_k(r, k, method=0):
    """Score is normalized discounted cumulative gain (ndcg)

    Relevance is positive real values.  Can use binary
    as the previous methods.

    Example from
    http://www.stanford.edu/class/cs276/handouts/EvaluationNew-handout-6-per.pdf
    >>> r = [3, 2, 3, 0, 0, 1, 2, 2, 3, 0]
    >>> ndcg_at_k(r, 1)
    1.0
    >>> r = [2, 1, 2, 0]
    >>> ndcg_at_k(r, 4)
    0.9203032077642922
    >>> ndcg_at_k(r, 4, method=1)
    0.96519546960144276
    >>> ndcg_at_k([0], 1)
    0.0
    >>> ndcg_at_k([1], 2)
    1.0

    Args:
        r: Relevance scores (list or numpy) in rank order
            (first element is the first item)
        k: Number of results to consider
        method: If 0 then weights are [1.0, 1.0, 0.6309, 0.5, 0.4307, ...]
                If 1 then weights are [1.0, 0.6309, 0.5, 0.4307, ...]

    Returns:
        Normalized discounted cumulative gain
    """
    dcg_max = dcg_at_k(sorted(r, reverse=True), k, method)
    if not dcg_max:
        return 0.
    return dcg_at_k(r, k, method) / dcg_max

# %%
mean_reciprocal_rank(ranked_list)
# Out:
# /tmp/meng/ipykernel_3443986/3935309969.py:24: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(arr).nonzero()` if the old behavior was intended.
#   rs = (np.asarray(r).nonzero()[0] for r in rs)
# 0.013872832369942197

# %%
r_precision(ranked_list)
# Out:
# 0.014169741697416974

# %%
average_precision(ranked_list)
# Out:
# 0.03123932341363698

# %%
positives =
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '../labels/labels_tif/porphyry_copper_sites_cont_US_clipped.tif' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 temp_data = gpd.read_file('../labels/labels_tif/porphyry_copper_sites_cont_US_clipped.tif')
#
# File /data/meng/anaconda3/envs/geolm/lib/python3.9/site-packages/geopandas/io/file.py:297, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     294     else:
#     295         path_or_bytes = filename
# --> 297     return _read_file_fiona(
# ...
